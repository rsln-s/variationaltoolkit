# %%
from variationaltoolkit.stuart_mis_utils.stuartansatzfunctions import stuart_one_run
# Out:
# Can't find the mpsbackend module, continuing without it
# [2020-10-08 13:38:20,364] {c:\users\kevin gui\documents\github\variationaltoolkit\variationaltoolkit\__init__.py:19} WARNING - Failed loading VariationalQuantumOptimizerAPOSMM, ignoring the following error: 'No module named 'mpi4py''

# %%
import networkx as nx
elist = [[0,2],[0,4],[1,2],[1,4],[0,3],[1,3]]
G = nx.OrderedGraph()
G.add_edges_from(elist)
# w = nx.adjacency_matrix(G, nodelist=range(G.number_of_nodes()))
nx.draw(G)

# %%
from qiskit.tools.visualization import plot_histogram
counts, res = stuart_one_run(1, G, initial_state_string='11100')
# plot_histogram(counts, title= 'p = ' + str(1) + ', initial state = 00000')
# Out:
# Found optimal solution: (-3, array([1, 1, 1, 0, 0]))
